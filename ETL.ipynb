# %%
# Import dependencies
import pandas as pd
import numpy as np
# from sqlalchemy import create_engine

# %%
# Read in data
file_path = './beer_reviews.csv'
beer_df = pd.read_csv(file_path)
beer_df.head()
# Out:
#    brewery_id             brewery_name  review_time  review_overall  \
# 0       10325          Vecchio Birraio   1234817823             1.5
# 1       10325          Vecchio Birraio   1235915097             3.0
# 2       10325          Vecchio Birraio   1235916604             3.0
# 3       10325          Vecchio Birraio   1234725145             3.0
# 4        1075  Caldera Brewing Company   1293735206             4.0
#
#    review_aroma  review_appearance review_profilename  \
# 0           2.0                2.5            stcules
# 1           2.5                3.0            stcules
# 2           2.5                3.0            stcules
# 3           3.0                3.5            stcules
# 4           4.5                4.0     johnmichaelsen
#
#                        beer_style  review_palate  review_taste  \
# 0                      Hefeweizen            1.5           1.5
# 1              English Strong Ale            3.0           3.0
# ...

# %%
# Filter dataframe into desired columns
# final_table_columns = ['review_overall', 'review_aroma', 'review_appearance', 'review_palate', 'review_taste']
# clean_beer_df = beer_df.drop(columns=[col for col in beer_df if col not in final_table_columns], inplace=True)

# %%
# Clean data
clean_beer_df = beer_df[['review_overall', 'review_aroma', 'review_appearance', 'review_palate', 'review_taste']]

# %%
clean_beer_df.dropna()
# Out:
#          review_overall  review_aroma  review_appearance  review_palate  \
# 0                   1.5           2.0                2.5            1.5
# 1                   3.0           2.5                3.0            3.0
# 2                   3.0           2.5                3.0            3.0
# 3                   3.0           3.0                3.5            2.5
# 4                   4.0           4.5                4.0            4.0
# ...                 ...           ...                ...            ...
# 1586609             5.0           4.0                3.5            4.0
# 1586610             4.0           5.0                2.5            2.0
# 1586611             4.5           3.5                3.0            3.5
# 1586612             4.0           4.5                4.5            4.5
# 1586613             5.0           4.5                4.5            4.5
#
#          review_taste
# 0                 1.5
# 1                 3.0
# 2                 3.0
# ...

# %%
clean_beer_df['review_overall'].value_counts()
# Out:
# 4.0    582764
# 4.5    324385
# 3.5    301817
# 3.0    165644
# 5.0     91320
# 2.5     58523
# 2.0     38225
# 1.5     12975
# 1.0     10954
# 0.0         7
# Name: review_overall, dtype: int64

# %%
# Export to database
clean_beer_df.to_csv('./Resources/clean_beer.csv', index=False)
